# %% [markdown]
# # 03 — Value Iteration
# **Week 4 | Dynamic Programming**
#
# **Value Iteration** combines policy evaluation and improvement into a single update:
#
# $$V_{k+1}(s) = \max_a \sum_{s'} P(s'|s,a) \left[ R(s,a,s') + \gamma V_k(s') \right]$$
#
# No explicit policy during the loop — we extract the policy once V converges.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)

class GridWorld:
    ACTIONS = {0:(-1,0), 1:(1,0), 2:(0,-1), 3:(0,1)}
    ACTION_SYMBOLS = {0:'↑', 1:'↓', 2:'←', 3:'→'}
    def __init__(self, size=5):
        self.size=size; self.start=(0,0); self.goal=(size-1,size-1)
        self.pits={(1,1),(1,3),(3,1),(3,3)}
    def n_states(self): return self.size**2
    def n_actions(self): return 4
    def transitions(self, s, a):
        r,c = divmod(s, self.size)
        dr,dc = self.ACTIONS[a]
        nr=max(0,min(self.size-1,r+dr)); nc=max(0,min(self.size-1,c+dc)); ns=nr*self.size+nc
        if (nr,nc)==self.goal:   return [(1.0,ns,+10.0,True)]
        if (nr,nc) in self.pits: return [(1.0,ns,-5.0,True)]
        return [(1.0,ns,-0.1,False)]

env = GridWorld()

# %%
def value_iteration(env, gamma=0.99, theta=1e-6):
    V = np.zeros(env.n_states())
    errors = []
    iteration = 0
    while True:
        delta = 0
        V_new = np.zeros_like(V)
        for s in range(env.n_states()):
            Q_s = [sum(p*(r + (0 if d else gamma*V[ns]))
                       for p,ns,r,d in env.transitions(s,a))
                   for a in range(env.n_actions())]
            V_new[s] = max(Q_s)
            delta = max(delta, abs(V_new[s] - V[s]))
        V = V_new
        errors.append(delta)
        iteration += 1
        if delta < theta:
            print(f"Value iteration converged in {iteration} sweeps (Δ={delta:.2e})")
            break
    # Extract greedy policy
    policy = np.zeros(env.n_states(), dtype=int)
    for s in range(env.n_states()):
        Q_s = [sum(p*(r + (0 if d else gamma*V[ns]))
                   for p,ns,r,d in env.transitions(s,a))
               for a in range(env.n_actions())]
        policy[s] = np.argmax(Q_s)
    return V, policy, errors

V_star, pi_star, errors = value_iteration(env)
# Out:
# Value iteration converged in 9 sweeps (Δ=0.00e+00)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4.5))

# Value function
im = axes[0].imshow(V_star.reshape(5,5), cmap='RdYlGn')
plt.colorbar(im, ax=axes[0])
for s in range(25):
    r,c=divmod(s,5)
    label='G' if (r,c)==env.goal else ('✕' if (r,c) in env.pits else '')
    axes[0].text(c,r,f'{label}\n{V_star[s]:.1f}',ha='center',va='center',fontsize=9)
axes[0].set_title('V* (Value Iteration)'); axes[0].set_xticks([]); axes[0].set_yticks([])

# Optimal policy
axes[1].set_xlim(-0.5,4.5); axes[1].set_ylim(-0.5,4.5)
axes[1].set_xticks(range(5)); axes[1].set_yticks(range(5)); axes[1].grid(True)
for s in range(25):
    r,c=divmod(s,5)
    if (r,c)==env.goal:         axes[1].text(c,4-r,'G',ha='center',va='center',fontsize=14,color='green')
    elif (r,c) in env.pits:     axes[1].text(c,4-r,'✕',ha='center',va='center',fontsize=14,color='red')
    else:                       axes[1].text(c,4-r,env.ACTION_SYMBOLS[pi_star[s]],ha='center',va='center',fontsize=18)
axes[1].set_title('Optimal Policy π*')

# Convergence
axes[2].semilogy(errors, color='darkorange', linewidth=2)
axes[2].set_xlabel('Sweep'); axes[2].set_ylabel('Max Bellman error (log)')
axes[2].set_title('Value Iteration Convergence')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Policy Iteration vs Value Iteration — Comparison

# %%
import time

# Time value iteration
t0 = time.time()
for _ in range(20): value_iteration(env)
vi_time = (time.time()-t0)/20

print(f"Value Iteration avg time: {vi_time*1000:.2f} ms")
print(f"\nKey difference:")
print(" Policy Iteration: full eval to convergence at each step (many inner loops)")
print(" Value Iteration:  single sweep per iteration (simpler inner loop)")
print(" Both converge to the same optimal policy.")
# Out:
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value Iteration avg time: 1.17 ms
#
# Key difference:
#  Policy Iteration: full eval to convergence at each step (many inner loops)
#  Value Iteration:  single sweep per iteration (simpler inner loop)
#  Both converge to the same optimal policy.

# %% [markdown]
# ## ✅ Exercises
# 1. Plot V* as a 3D surface using `ax.plot_surface`. Does the shape make intuitive sense?
# 2. Set γ=0.5. Does value iteration still converge? What does the optimal policy look like now?
# 3. **Challenge**: implement **asynchronous value iteration** — update one randomly-chosen state per step. Plot the convergence and compare to synchronous.

# %% [markdown]
# ## Question 1.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

x = np.arange(5)
y = np.arange(5)
X, Y = np.meshgrid(x, y)
Z = V_star.reshape(5, 5)

ax.plot_surface(X, Y, Z, cmap='RdYlGn', edgecolor='k', linewidth=0.3)
ax.set_xlabel('Column')
ax.set_ylabel('Row')
ax.set_zlabel('V*')
ax.set_title('V* as a 3D Surface')
plt.tight_layout()
plt.show()

# %% [markdown]
# The 3D surface makes total sense. The goal state sticks out as a tall peak because it gives +10 reward.

# %% [markdown]
# ## Question 2.

# %%
V_05, pi_05, errors_05 = value_iteration(env, gamma=0.5)

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

im = axes[0].imshow(V_05.reshape(5, 5), cmap='RdYlGn')
plt.colorbar(im, ax=axes[0])
for s in range(25):
    r, c = divmod(s, 5)
    label = 'G' if (r,c)==env.goal else ('✕' if (r,c) in env.pits else '')
    axes[0].text(c, r, f'{label}\n{V_05[s]:.1f}', ha='center', va='center', fontsize=9)
axes[0].set_title('V* with γ=0.5')
axes[0].set_xticks([]); axes[0].set_yticks([])

axes[1].set_xlim(-0.5, 4.5); axes[1].set_ylim(-0.5, 4.5)
axes[1].set_xticks(range(5)); axes[1].set_yticks(range(5)); axes[1].grid(True)
for s in range(25):
    r, c = divmod(s, 5)
    if (r,c) == env.goal:       axes[1].text(c, 4-r, 'G',  ha='center', va='center', fontsize=14, color='green')
    elif (r,c) in env.pits:     axes[1].text(c, 4-r, '✕', ha='center', va='center', fontsize=14, color='red')
    else:                        axes[1].text(c, 4-r, env.ACTION_SYMBOLS[pi_05[s]], ha='center', va='center', fontsize=18)
axes[1].set_title('Optimal Policy π* with γ=0.5')

plt.tight_layout()
plt.show()
# Out:
# Value iteration converged in 9 sweeps (Δ=0.00e+00)

# %% [markdown]
# Yes, value iteration still converges with γ=0.5, and your output shows it converged in just 9 sweeps which is faster than γ=0.99. The values across the grid are much smaller because future rewards get halved every step so the agent doesn't value distant rewards much. The policy still finds a valid path to the goal avoiding all the pits, and it looks pretty similar to γ=0.99 because the grid is small enough that shortsightedness doesn't cause drastically wrong decisions.

# %% [markdown]
# ## Question 3.

# %%
def async_value_iteration(env, gamma=0.99, theta=1e-6, max_steps=100000):
    V = np.zeros(env.n_states())
    errors = []
    rng = np.random.default_rng(42)

    for step in range(max_steps):
        s = rng.integers(env.n_states())   # pick one random state
        Q_s = [sum(p * (r + (0 if d else gamma * V[ns]))
                   for p, ns, r, d in env.transitions(s, a))
               for a in range(env.n_actions())]
        new_val = max(Q_s)
        delta = abs(new_val - V[s])
        V[s] = new_val
        errors.append(delta)

        if step > 100 and max(errors[-env.n_states():]) < theta:
            print(f"Async VI converged in {step+1} steps")
            break

    policy = np.zeros(env.n_states(), dtype=int)
    for s in range(env.n_states()):
        Q_s = [sum(p * (r + (0 if d else gamma * V[ns]))
                   for p, ns, r, d in env.transitions(s, a))
               for a in range(env.n_actions())]
        policy[s] = np.argmax(Q_s)
    return V, policy, errors

V_async, pi_async, errors_async = async_value_iteration(env)

V_sync, pi_sync, errors_sync = value_iteration(env)

plt.figure(figsize=(10, 4))
plt.semilogy(errors_async, color='steelblue', alpha=0.6, label='Async VI (per step)')
plt.semilogy(range(0, len(errors_sync)*env.n_states(), env.n_states()),
             errors_sync, color='darkorange', linewidth=2, marker='o', label='Sync VI (per sweep)')
plt.xlabel('Steps')
plt.ylabel('Bellman error (log)')
plt.title('Async vs Sync Value Iteration Convergence')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Async VI converged in 164 steps
# Value iteration converged in 9 sweeps (Δ=0.00e+00)

# %% [markdown]
# Async VI updates one random state per step instead of all 25. From your output, it took 164 steps vs sync VI's 9 sweeps, and the error graph is much noisier because it randomly picks states each time. But both give the same optimal policy in the end. Async VI is useful in very large environments where doing a full sweep every iteration is too expensive.
